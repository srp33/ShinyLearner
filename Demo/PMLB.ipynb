# %% [markdown]
# ## ShinyLearner: Using PMLB Datasets

# %% [markdown]
# The Penn Machine Learning Benchmarks (PMLB) team has provided a Python wrapper named `pmlb`, which can be installed on Python via `pip`.

# %%
# !pip install pmlb
# Out:
# Requirement already satisfied: pmlb in /Users/EricaSuh/.local/lib/python3.6/site-packages (0.3)
# Requirement already satisfied: pandas in /Users/EricaSuh/.local/lib/python3.6/site-packages (from pmlb) (0.23.3)
# Requirement already satisfied: numpy>=1.9.0 in /Users/EricaSuh/.local/lib/python3.6/site-packages (from pandas->pmlb) (1.14.5)
# Requirement already satisfied: pytz>=2011k in /Users/EricaSuh/.local/lib/python3.6/site-packages (from pandas->pmlb) (2018.5)
# Requirement already satisfied: python-dateutil>=2.5.0 in /Users/EricaSuh/.local/lib/python3.6/site-packages (from pandas->pmlb) (2.7.3)
# Requirement already satisfied: six>=1.5 in /Users/EricaSuh/.local/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas->pmlb) (1.11.0)
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# As an example, we will fetch 10 biology-related datasets from PMLB.

# %%
datasets = ['analcatdata_aids',
			'ann-thyroid',
			'breast-cancer',
			'dermatology',
			'diabetes',
			'hepatitis',
            'iris',
			'liver-disorder',
			'molecular-biology_promoters',
			'yeast']

# %% [markdown]
# PMLB's [GitHub repository](https://github.com/EpistasisLab/penn-ml-benchmarks) demonstrates how `pmlb` is used in Python scripts. In addition, ShinyLearner requires that input data files have exactly one feature named 'Class.' After making the appropriate changes, we will save the dataframe to a file with a [supported file extension](https://github.com/srp33/ShinyLearner/blob/master/InputFormats.md).

# %%
from pmlb import fetch_data

for data in datasets:
	curr_data = fetch_data(data)
	curr_data = curr_data.rename(columns={'target': 'Class'})  # 'target' is renamed to 'Class'
	curr_data.to_csv('./new_{}.tsv'.format(data), sep='\t', index=True)  # Saved to a .tsv file

# %% [markdown]
# This [web application](http://bioapps.byu.edu/shinylearnerweb/) allows us to build ShinyLearner commands more easily. By following the step-by-step process, we obtained the command below and will run it with each dataset to get the output files.

# %%
# %%bash
#
# function runShinyLearner {
#   localInFileName="$1"
#   description="$2"
#
#   /UserScripts/nestedclassification_montecarlo \
#     --data "InputData/$localInFileName" \
#     --description "$description" \
#     --outer-iterations 5 \
#     --inner-iterations 2 \
#     --classif-algo "AlgorithmScripts/Classification/tsv/sklearn/svm/default*,AlgorithmScripts/Classification/tsv/mlr/earth/default*,AlgorithmScripts/Classification/tsv/mlr/h2o.randomForest/default*,AlgorithmScripts/Classification/tsv/sklearn/decision_tree/default*,AlgorithmScripts/Classification/tsv/sklearn/logistic_regression/default*,AlgorithmScripts/Classification/arff/weka/HoeffdingTree/default*,AlgorithmScripts/Classification/arff/weka/MultilayerPerceptron/default*,AlgorithmScripts/Classification/tsv/mlr/mlp/default*,AlgorithmScripts/Classification/tsv/sklearn/multilayer_perceptron/default*,AlgorithmScripts/Classification/arff/weka/SimpleLogistic/default*" \
#     --output-dir "OutputData" \
#     --ohe true \
#     --scale true \
#     --impute true \
#     --verbose false
# }
#
# for dataset in "analcatdata_aids" "iris"
# do
#   runShinyLearner "new_${dataset}.tsv" "${dataset}"
# done
#
# #runShinyLearner "new_analcatdata_aids.tsv" "analcatdata_aids"
# #runShinyLearner "/Users/EricaSuh/shinylearner" "/Users/EricaSuh/shinylearner/ann-thyroid" "new_ann-thyroid.tsv" "ann-thyroid"
# #runShinyLearner "/Users/EricaSuh/shinylearner" "/Users/EricaSuh/shinylearner/breast-cancer" "new_breast-cancer.tsv" "breast-cancer"
# #runShinyLearner "/Users/EricaSuh/shinylearner" "/Users/EricaSuh/shinylearner/dermatology" "new_dermatology.tsv" "dermatology"
# #runShinyLearner "/Users/EricaSuh/shinylearner" "/Users/EricaSuh/shinylearner/diabetes" "new_diabetes.tsv" "diabetes"
# #runShinyLearner "/Users/EricaSuh/shinylearner" "/Users/EricaSuh/shinylearner/hepatitis" "new_hepatitis.tsv" "hepatitis"
# #runShinyLearner "/Users/EricaSuh/shinylearner" "/Users/EricaSuh/shinylearner/iris" "new_iris.tsv" "iris"
# #runShinyLearner "/Users/EricaSuh/shinylearner" "/Users/EricaSuh/shinylearner/liver-disorder" "new_liver-disorder.tsv" "liver-disorder"
# #runShinyLearner "/Users/EricaSuh/shinylearner" "/Users/EricaSuh/shinylearner/molecular-biology_promoters" "new_molecular-biology_promoters.tsv" "molecular-biology_promoters"
# #runShinyLearner "/Users/EricaSuh/shinylearner" "/Users/EricaSuh/shinylearner/yeast" "new_yeast.tsv" "yeast"
# Out:
# ***********************************************************************
# Command that was executed for analysis on Mon Aug  6 18:21:35 UTC 2018:
#
# /UserScripts/nestedclassification_montecarlo --data InputData/new_analcatdata_aids.tsv --description analcatdata_aids --outer-iterations 5 --inner-iterations 2 --classif-algo AlgorithmScripts/Classification/tsv/sklearn/svm/default*,AlgorithmScripts/Classification/tsv/mlr/earth/default*,AlgorithmScripts/Classification/tsv/mlr/h2o.randomForest/default*,AlgorithmScripts/Classification/tsv/sklearn/decision_tree/default*,AlgorithmScripts/Classification/tsv/sklearn/logistic_regression/default*,AlgorithmScripts/Classification/arff/weka/HoeffdingTree/default*,AlgorithmScripts/Classification/arff/weka/MultilayerPerceptron/default*,AlgorithmScripts/Classification/tsv/mlr/mlp/default*,AlgorithmScripts/Classification/tsv/sklearn/multilayer_perceptron/default*,AlgorithmScripts/Classification/arff/weka/SimpleLogistic/default* --output-dir OutputData --ohe true --scale true --impute true --verbose false
#
# ShinyLearner version: 407
# ***********************************************************************
#
# [2018-08-06 18:21:35] Parsing data...
# [2018-08-06 18:21:36] After filtering, data were available for 50 instances and 5 data points.
# [2018-08-06 18:21:36] Imputing missing data (where applicable)...
# [2018-08-06 18:21:37] One-hot encoding categorical data (where applicable)...
# [2018-08-06 18:21:37] Scaling numerical data (where applicable)...
# [2018-08-06 18:21:38] Classifying for inner iterations...
# [2018-08-06 18:25:23] Calculating classification metrics for inner iterations...
# [2018-08-06 18:25:28] Parsing inner classification results...
# [2018-08-06 18:25:28] Identifying best combination of algorithms...
# [2018-08-06 18:25:29] Classifying for outer iterations...
# [2018-08-06 18:26:43] Calculating classification metrics for outer iterations...
# [2018-08-06 18:26:46] Preparing output files...
# [2018-08-06 18:26:46] Analysis completed!
# ***********************************************************************
# Command that was executed for analysis on Mon Aug  6 18:26:49 UTC 2018:
#
# /UserScripts/nestedclassification_montecarlo --data InputData/new_ann-thyroid.tsv --description ann-thyroid --outer-iterations 5 --inner-iterations 2 --classif-algo AlgorithmScripts/Classification/tsv/sklearn/svm/default*,AlgorithmScripts/Classification/tsv/mlr/earth/default*,AlgorithmScripts/Classification/tsv/mlr/h2o.randomForest/default*,AlgorithmScripts/Classification/tsv/sklearn/decision_tree/default*,AlgorithmScripts/Classification/tsv/sklearn/logistic_regression/default*,AlgorithmScripts/Classification/arff/weka/HoeffdingTree/default*,AlgorithmScripts/Classification/arff/weka/MultilayerPerceptron/default*,AlgorithmScripts/Classification/tsv/mlr/mlp/default*,AlgorithmScripts/Classification/tsv/sklearn/multilayer_perceptron/default*,AlgorithmScripts/Classification/arff/weka/SimpleLogistic/default* --output-dir OutputData --ohe true --scale true --impute true --verbose false
#
# ShinyLearner version: 407
# ***********************************************************************
#
# [2018-08-06 18:26:49] Parsing data...
# [2018-08-06 18:26:50] After filtering, data were available for 7200 instances and 22 data points.
# [2018-08-06 18:26:50] Imputing missing data (where applicable)...
# [2018-08-06 18:26:52] One-hot encoding categorical data (where applicable)...
# [2018-08-06 18:26:52] Scaling numerical data (where applicable)...
# [2018-08-06 18:26:59] Classifying for inner iterations...
# [2018-08-06 18:33:28] Calculating classification metrics for inner iterations...
# [2018-08-06 18:33:36] Parsing inner classification results...
# [2018-08-06 18:33:36] Identifying best combination of algorithms...
# [2018-08-06 18:33:37] Classifying for outer iterations...
# [2018-08-06 18:37:39] Calculating classification metrics for outer iterations...
# [2018-08-06 18:37:45] Preparing output files...
# [2018-08-06 18:37:52] Analysis completed!
# ***********************************************************************
# Command that was executed for analysis on Mon Aug  6 18:37:56 UTC 2018:
#
# /UserScripts/nestedclassification_montecarlo --data InputData/new_breast-cancer.tsv --description breast-cancer --outer-iterations 5 --inner-iterations 2 --classif-algo AlgorithmScripts/Classification/tsv/sklearn/svm/default*,AlgorithmScripts/Classification/tsv/mlr/earth/default*,AlgorithmScripts/Classification/tsv/mlr/h2o.randomForest/default*,AlgorithmScripts/Classification/tsv/sklearn/decision_tree/default*,AlgorithmScripts/Classification/tsv/sklearn/logistic_regression/default*,AlgorithmScripts/Classification/arff/weka/HoeffdingTree/default*,AlgorithmScripts/Classification/arff/weka/MultilayerPerceptron/default*,AlgorithmScripts/Classification/tsv/mlr/mlp/default*,AlgorithmScripts/Classification/tsv/sklearn/multilayer_perceptron/default*,AlgorithmScripts/Classification/arff/weka/SimpleLogistic/default* --output-dir OutputData --ohe true --scale true --impute true --verbose false
#
# ShinyLearner version: 407
# ***********************************************************************
#
# [2018-08-06 18:37:57] Parsing data...
# [2018-08-06 18:37:57] After filtering, data were available for 286 instances and 10 data points.
# [2018-08-06 18:37:57] Imputing missing data (where applicable)...
# [2018-08-06 18:37:58] One-hot encoding categorical data (where applicable)...
# [2018-08-06 18:37:58] Scaling numerical data (where applicable)...
# [2018-08-06 18:37:59] Classifying for inner iterations...
# [2018-08-06 18:40:43] Calculating classification metrics for inner iterations...
# [2018-08-06 18:40:46] Parsing inner classification results...
# [2018-08-06 18:40:46] Identifying best combination of algorithms...
# [2018-08-06 18:40:47] Classifying for outer iterations...
# [2018-08-06 18:42:02] Calculating classification metrics for outer iterations...
# [2018-08-06 18:42:05] Preparing output files...
# [2018-08-06 18:42:06] Analysis completed!
# ***********************************************************************
# Command that was executed for analysis on Mon Aug  6 18:42:08 UTC 2018:
#
# /UserScripts/nestedclassification_montecarlo --data InputData/new_dermatology.tsv --description dermatology --outer-iterations 5 --inner-iterations 2 --classif-algo AlgorithmScripts/Classification/tsv/sklearn/svm/default*,AlgorithmScripts/Classification/tsv/mlr/earth/default*,AlgorithmScripts/Classification/tsv/mlr/h2o.randomForest/default*,AlgorithmScripts/Classification/tsv/sklearn/decision_tree/default*,AlgorithmScripts/Classification/tsv/sklearn/logistic_regression/default*,AlgorithmScripts/Classification/arff/weka/HoeffdingTree/default*,AlgorithmScripts/Classification/arff/weka/MultilayerPerceptron/default*,AlgorithmScripts/Classification/tsv/mlr/mlp/default*,AlgorithmScripts/Classification/tsv/sklearn/multilayer_perceptron/default*,AlgorithmScripts/Classification/arff/weka/SimpleLogistic/default* --output-dir OutputData --ohe true --scale true --impute true --verbose false
#
# ShinyLearner version: 407
# ***********************************************************************
#
# [2018-08-06 18:42:08] Parsing data...
# [2018-08-06 18:42:08] After filtering, data were available for 366 instances and 35 data points.
# [2018-08-06 18:42:08] Imputing missing data (where applicable)...
# [2018-08-06 18:42:09] One-hot encoding categorical data (where applicable)...
# [2018-08-06 18:42:10] Scaling numerical data (where applicable)...
# [2018-08-06 18:42:11] Classifying for inner iterations...
# [2018-08-06 18:45:17] Calculating classification metrics for inner iterations...
# [2018-08-06 18:45:24] Parsing inner classification results...
# [2018-08-06 18:45:25] Identifying best combination of algorithms...
# [2018-08-06 18:45:25] Classifying for outer iterations...
# [2018-08-06 18:47:02] Calculating classification metrics for outer iterations...
# [2018-08-06 18:47:06] Preparing output files...
# [2018-08-06 18:47:06] Analysis completed!
# ***********************************************************************
# Command that was executed for analysis on Mon Aug  6 18:47:08 UTC 2018:
#
# /UserScripts/nestedclassification_montecarlo --data InputData/new_diabetes.tsv --description diabetes --outer-iterations 5 --inner-iterations 2 --classif-algo AlgorithmScripts/Classification/tsv/sklearn/svm/default*,AlgorithmScripts/Classification/tsv/mlr/earth/default*,AlgorithmScripts/Classification/tsv/mlr/h2o.randomForest/default*,AlgorithmScripts/Classification/tsv/sklearn/decision_tree/default*,AlgorithmScripts/Classification/tsv/sklearn/logistic_regression/default*,AlgorithmScripts/Classification/arff/weka/HoeffdingTree/default*,AlgorithmScripts/Classification/arff/weka/MultilayerPerceptron/default*,AlgorithmScripts/Classification/tsv/mlr/mlp/default*,AlgorithmScripts/Classification/tsv/sklearn/multilayer_perceptron/default*,AlgorithmScripts/Classification/arff/weka/SimpleLogistic/default* --output-dir OutputData --ohe true --scale true --impute true --verbose false
#
# ShinyLearner version: 407
# ***********************************************************************
#
# [2018-08-06 18:47:08] Parsing data...
# [2018-08-06 18:47:09] After filtering, data were available for 768 instances and 9 data points.
# [2018-08-06 18:47:09] Imputing missing data (where applicable)...
# [2018-08-06 18:47:09] One-hot encoding categorical data (where applicable)...
# [2018-08-06 18:47:10] Scaling numerical data (where applicable)...
# [2018-08-06 18:47:11] Classifying for inner iterations...
# [2018-08-06 18:50:04] Calculating classification metrics for inner iterations...
# [2018-08-06 18:50:07] Parsing inner classification results...
# [2018-08-06 18:50:08] Identifying best combination of algorithms...
# [2018-08-06 18:50:09] Classifying for outer iterations...
# [2018-08-06 18:51:29] Calculating classification metrics for outer iterations...
# [2018-08-06 18:51:32] Preparing output files...
# [2018-08-06 18:51:33] Analysis completed!
# ***********************************************************************
# Command that was executed for analysis on Mon Aug  6 18:51:36 UTC 2018:
#
# /UserScripts/nestedclassification_montecarlo --data InputData/new_hepatitis.tsv --description hepatitis --outer-iterations 5 --inner-iterations 2 --classif-algo AlgorithmScripts/Classification/tsv/sklearn/svm/default*,AlgorithmScripts/Classification/tsv/mlr/earth/default*,AlgorithmScripts/Classification/tsv/mlr/h2o.randomForest/default*,AlgorithmScripts/Classification/tsv/sklearn/decision_tree/default*,AlgorithmScripts/Classification/tsv/sklearn/logistic_regression/default*,AlgorithmScripts/Classification/arff/weka/HoeffdingTree/default*,AlgorithmScripts/Classification/arff/weka/MultilayerPerceptron/default*,AlgorithmScripts/Classification/tsv/mlr/mlp/default*,AlgorithmScripts/Classification/tsv/sklearn/multilayer_perceptron/default*,AlgorithmScripts/Classification/arff/weka/SimpleLogistic/default* --output-dir OutputData --ohe true --scale true --impute true --verbose false
#
# ShinyLearner version: 407
# ***********************************************************************
#
# [2018-08-06 18:51:36] Parsing data...
# [2018-08-06 18:51:36] After filtering, data were available for 155 instances and 20 data points.
# [2018-08-06 18:51:37] Imputing missing data (where applicable)...
# [2018-08-06 18:51:38] One-hot encoding categorical data (where applicable)...
# [2018-08-06 18:51:39] Scaling numerical data (where applicable)...
# [2018-08-06 18:51:40] Classifying for inner iterations...
# [2018-08-06 18:54:24] Calculating classification metrics for inner iterations...
# [2018-08-06 18:54:27] Parsing inner classification results...
# [2018-08-06 18:54:27] Identifying best combination of algorithms...
# [2018-08-06 18:54:29] Classifying for outer iterations...
# [2018-08-06 18:55:45] Calculating classification metrics for outer iterations...
# [2018-08-06 18:55:48] Preparing output files...
# [2018-08-06 18:55:48] Analysis completed!
# ***********************************************************************
# Command that was executed for analysis on Mon Aug  6 18:55:50 UTC 2018:
#
# /UserScripts/nestedclassification_montecarlo --data InputData/new_iris.tsv --description iris --outer-iterations 5 --inner-iterations 2 --classif-algo AlgorithmScripts/Classification/tsv/sklearn/svm/default*,AlgorithmScripts/Classification/tsv/mlr/earth/default*,AlgorithmScripts/Classification/tsv/mlr/h2o.randomForest/default*,AlgorithmScripts/Classification/tsv/sklearn/decision_tree/default*,AlgorithmScripts/Classification/tsv/sklearn/logistic_regression/default*,AlgorithmScripts/Classification/arff/weka/HoeffdingTree/default*,AlgorithmScripts/Classification/arff/weka/MultilayerPerceptron/default*,AlgorithmScripts/Classification/tsv/mlr/mlp/default*,AlgorithmScripts/Classification/tsv/sklearn/multilayer_perceptron/default*,AlgorithmScripts/Classification/arff/weka/SimpleLogistic/default* --output-dir OutputData --ohe true --scale true --impute true --verbose false
#
# ShinyLearner version: 407
# ***********************************************************************
#
# [2018-08-06 18:55:51] Parsing data...
# [2018-08-06 18:55:51] After filtering, data were available for 150 instances and 5 data points.
# [2018-08-06 18:55:51] Imputing missing data (where applicable)...
# [2018-08-06 18:55:52] One-hot encoding categorical data (where applicable)...
# [2018-08-06 18:55:52] Scaling numerical data (where applicable)...
# [2018-08-06 18:55:53] Classifying for inner iterations...
# [2018-08-06 18:58:25] Calculating classification metrics for inner iterations...
# [2018-08-06 18:58:28] Parsing inner classification results...
# [2018-08-06 18:58:28] Identifying best combination of algorithms...
# [2018-08-06 18:58:29] Classifying for outer iterations...
# [2018-08-06 18:59:40] Calculating classification metrics for outer iterations...
# [2018-08-06 18:59:43] Preparing output files...
# [2018-08-06 18:59:43] Analysis completed!
# ***********************************************************************
# Command that was executed for analysis on Mon Aug  6 18:59:46 UTC 2018:
#
# /UserScripts/nestedclassification_montecarlo --data InputData/new_liver-disorder.tsv --description liver-disorder --outer-iterations 5 --inner-iterations 2 --classif-algo AlgorithmScripts/Classification/tsv/sklearn/svm/default*,AlgorithmScripts/Classification/tsv/mlr/earth/default*,AlgorithmScripts/Classification/tsv/mlr/h2o.randomForest/default*,AlgorithmScripts/Classification/tsv/sklearn/decision_tree/default*,AlgorithmScripts/Classification/tsv/sklearn/logistic_regression/default*,AlgorithmScripts/Classification/arff/weka/HoeffdingTree/default*,AlgorithmScripts/Classification/arff/weka/MultilayerPerceptron/default*,AlgorithmScripts/Classification/tsv/mlr/mlp/default*,AlgorithmScripts/Classification/tsv/sklearn/multilayer_perceptron/default*,AlgorithmScripts/Classification/arff/weka/SimpleLogistic/default* --output-dir OutputData --ohe true --scale true --impute true --verbose false
#
# ShinyLearner version: 407
# ***********************************************************************
#
# [2018-08-06 18:59:46] Parsing data...
# [2018-08-06 18:59:46] After filtering, data were available for 345 instances and 7 data points.
# [2018-08-06 18:59:46] Imputing missing data (where applicable)...
# [2018-08-06 18:59:47] One-hot encoding categorical data (where applicable)...
# [2018-08-06 18:59:47] Scaling numerical data (where applicable)...
# [2018-08-06 18:59:48] Classifying for inner iterations...
# [2018-08-06 19:02:18] Calculating classification metrics for inner iterations...
# [2018-08-06 19:02:21] Parsing inner classification results...
# [2018-08-06 19:02:21] Identifying best combination of algorithms...
# [2018-08-06 19:02:22] Classifying for outer iterations...
# [2018-08-06 19:03:38] Calculating classification metrics for outer iterations...
# [2018-08-06 19:03:40] Preparing output files...
# [2018-08-06 19:03:41] Analysis completed!
# ***********************************************************************
# Command that was executed for analysis on Mon Aug  6 19:03:43 UTC 2018:
#
# /UserScripts/nestedclassification_montecarlo --data InputData/new_molecular-biology_promoters.tsv --description molecular-biology_promoters --outer-iterations 5 --inner-iterations 2 --classif-algo AlgorithmScripts/Classification/tsv/sklearn/svm/default*,AlgorithmScripts/Classification/tsv/mlr/earth/default*,AlgorithmScripts/Classification/tsv/mlr/h2o.randomForest/default*,AlgorithmScripts/Classification/tsv/sklearn/decision_tree/default*,AlgorithmScripts/Classification/tsv/sklearn/logistic_regression/default*,AlgorithmScripts/Classification/arff/weka/HoeffdingTree/default*,AlgorithmScripts/Classification/arff/weka/MultilayerPerceptron/default*,AlgorithmScripts/Classification/tsv/mlr/mlp/default*,AlgorithmScripts/Classification/tsv/sklearn/multilayer_perceptron/default*,AlgorithmScripts/Classification/arff/weka/SimpleLogistic/default* --output-dir OutputData --ohe true --scale true --impute true --verbose false
#
# ShinyLearner version: 407
# ***********************************************************************
#
# [2018-08-06 19:03:43] Parsing data...
# [2018-08-06 19:03:44] After filtering, data were available for 106 instances and 59 data points.
# [2018-08-06 19:03:44] Imputing missing data (where applicable)...
# [2018-08-06 19:03:45] One-hot encoding categorical data (where applicable)...
# [2018-08-06 19:03:45] Scaling numerical data (where applicable)...
# [2018-08-06 19:03:46] Classifying for inner iterations...
# [2018-08-06 19:06:32] Calculating classification metrics for inner iterations...
# [2018-08-06 19:06:35] Parsing inner classification results...
# [2018-08-06 19:06:35] Identifying best combination of algorithms...
# [2018-08-06 19:06:36] Classifying for outer iterations...
# [2018-08-06 19:08:00] Calculating classification metrics for outer iterations...
# [2018-08-06 19:08:02] Preparing output files...
# [2018-08-06 19:08:03] Analysis completed!
# ***********************************************************************
# Command that was executed for analysis on Mon Aug  6 19:08:05 UTC 2018:
#
# /UserScripts/nestedclassification_montecarlo --data InputData/new_yeast.tsv --description yeast --outer-iterations 5 --inner-iterations 2 --classif-algo AlgorithmScripts/Classification/tsv/sklearn/svm/default*,AlgorithmScripts/Classification/tsv/mlr/earth/default*,AlgorithmScripts/Classification/tsv/mlr/h2o.randomForest/default*,AlgorithmScripts/Classification/tsv/sklearn/decision_tree/default*,AlgorithmScripts/Classification/tsv/sklearn/logistic_regression/default*,AlgorithmScripts/Classification/arff/weka/HoeffdingTree/default*,AlgorithmScripts/Classification/arff/weka/MultilayerPerceptron/default*,AlgorithmScripts/Classification/tsv/mlr/mlp/default*,AlgorithmScripts/Classification/tsv/sklearn/multilayer_perceptron/default*,AlgorithmScripts/Classification/arff/weka/SimpleLogistic/default* --output-dir OutputData --ohe true --scale true --impute true --verbose false
#
# ShinyLearner version: 407
# ***********************************************************************
#
# [2018-08-06 19:08:05] Parsing data...
# [2018-08-06 19:08:05] After filtering, data were available for 1479 instances and 9 data points.
# [2018-08-06 19:08:05] Imputing missing data (where applicable)...
# [2018-08-06 19:08:06] One-hot encoding categorical data (where applicable)...
# [2018-08-06 19:08:07] Scaling numerical data (where applicable)...
# [2018-08-06 19:08:08] Classifying for inner iterations...
# [2018-08-06 19:11:38] Calculating classification metrics for inner iterations...
# [2018-08-06 19:11:49] Parsing inner classification results...
# [2018-08-06 19:11:50] Identifying best combination of algorithms...
# [2018-08-06 19:11:51] Classifying for outer iterations...
# [2018-08-06 19:13:37] Calculating classification metrics for outer iterations...
# [2018-08-06 19:13:44] Preparing output files...
# [2018-08-06 19:13:45] Analysis completed!
